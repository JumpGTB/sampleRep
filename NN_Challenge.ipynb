# %% [markdown]
# <a href="https://colab.research.google.com/github/JumpGTB/sampleRep/blob/main/NN_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Networks Fashion MNIST Challenge

# %% [markdown]
# **MAKE A COPY OF THIS NOTEBOOK BEFORE YOU PROCEDE**
#
# Objective: I want all of you to do hands on challenge to train a neural network to do image classification.
#
# The dataset you will be using is Fashion MNIST.
#
# *   Prize: I'll send you $25 and you get the glory.
#
#
# *   Rules of the game:
#     1.  Your model must be a Neural Network
#     2.  You can help out someone who is less experienced and if you both win you will get $30 each.
#     3. If you are in a team of two, the less experienced person is the only one who can touch the keyword.
#
# May the best model win!
#
# I suggest that you refer back to the MNIST dataset we did last Friday: https://colab.research.google.com/drive/1_kze6BgjnA8aRIToxJDof7Q0pPlE-vGw?usp=sharing
#
# You can also use any resources you find on the web, [hint: There are probably some pretty Medium articles that can help....]

# %%
import torch
import numpy as np # for vectors
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt # this is used for graphing

# %%
# Define a transform to normalize the data
# the values have a mean of 0.5 and std of 0.5
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# Download and load the training data
train_set = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True) # makes the data iterable

# Download and load the test data
test_set = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=64, shuffle=True)
# Out:
# ...
# 100%|██████████| 26421880/26421880 [00:03<00:00, 8550410.25it/s]
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
#
# ...
# 100%|██████████| 29515/29515 [00:00<00:00, 137904.59it/s]
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
#
# ...
# 100%|██████████| 4422102/4422102 [00:01<00:00, 2570601.81it/s]
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
#
# ...
# 100%|██████████| 5148/5148 [00:00<00:00, 17042049.72it/s]
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw

# %%
# Get one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy()

# Plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):  # let's display 20 images
    ax = fig.add_subplot(2, 20//2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

plt.show()

# %% [markdown]
# Fill out this quick session feedback Google form at the end of the session, thank you!
# ![qr-code.png](data:image/png;base64,...)
#
# https://forms.gle/BpQRL2JxLGw5TuGcA
